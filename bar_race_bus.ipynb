# %%
import pandas as pd

# %%
race_df = pd.read_csv("Bus_monthly(weekday,weekend,total).csv")
race_df
# Out:
#       route                        routename Month_Beginning  \
# 0         1                Indiana/Hyde Park      01/01/2001
# 1         2                Hyde Park Express      01/01/2001
# 2         3                       King Drive      01/01/2001
# 3         4                    Cottage Grove      01/01/2001
# 4         6             Jackson Park Express      01/01/2001
# ...     ...                              ...             ...
# 31435   172            U. of Chicago/Kenwood      12/01/2019
# 31436   192  U. of Chicago Hospitals Express      12/01/2019
# 31437   201                    Central/Ridge      12/01/2019
# 31438   206              Evanston Circulator      12/01/2019
# 31439  1001      Shuttle/Special Event Route      12/01/2019
#
#        Avg_Weekday_Rides  Avg_Saturday_Rides  Avg_Sunday-Holiday_Rides  \
# 0                 6982.6                 0.0                       0.0
# 1                 1000.0                 0.0                       0.0
# ...

# %%
race_df = race_df.drop(["route","Avg_Weekday_Rides","Avg_Saturday_Rides","Avg_Sunday-Holiday_Rides"], axis = 1)

# %%
temp1  = race_df
temp1['year'] = pd.DatetimeIndex(temp1['Month_Beginning']).year
temp1 = temp1.drop(["Month_Beginning"],axis =1)
temp1 = temp1.groupby(["routename","year"]).mean().unstack()
#temp1 =temp1.nlargest(50,"MonthTotal")
# routes = list(temp1["routename"])
# routes
temp1.columns = temp1.columns.get_level_values(1)
temp1 = temp1.reset_index()
display(temp1)
temp1.to_csv('bar_race.csv', index=False)
# Out:
# year                routename           2001           2002           2003  \
# 0            111th/King Drive            NaN            NaN            NaN
# 1                   16th/18th   42694.833333   39767.416667   40980.000000
# 2                        31st            NaN            NaN            NaN
# 3                   31st/35th            NaN            NaN            NaN
# 4                        35th  159141.166667  155626.833333  141974.833333
# ..                        ...            ...            ...            ...
# 184               Westchester   12541.583333   11155.250000   10917.666667
# 185                   Western  665532.166667  638706.666667  576772.500000
# 186           Western Express  123700.833333  141472.666667  177153.500000
# 187   Wilson/Michigan Express  198168.083333  200526.333333  168425.000000
# 188     Wrigley Field Express     221.857143    1076.500000    2500.000000
#
# year           2004           2005           2006           2007  \
# ...

# %%
race_df = race_df.loc[race_df["routename"].isin(routes)]

# %%
race_df
# Out:
#                           routename Month_Beginning  MonthTotal
# 2                        King Drive      01/01/2001      567413
# 3                     Cottage Grove      01/01/2001      618796
# 4              Jackson Park Express      01/01/2001      493926
# 6                           Halsted      01/01/2001      521892
# 8                           Ashland      01/01/2001      811006
# ...                             ...             ...         ...
# 31400              South California      12/01/2019      193491
# 31424  Inner Drive/Michigan Express      12/01/2019      326930
# 31425           Outer Drive Express      12/01/2019      290915
# 31427                      Sheridan      12/01/2019      396196
# 31428                       Addison      12/01/2019      203058
#
# [10919 rows x 3 columns]

# %%
race_df.to_csv('bar_race.csv', index=False)

# %%
from IPython.display import HTML

HTML("""
<div class="flourish-embed flourish-bar-chart-race" data-src="visualisation/2187019" data-url="https://flo.uri.sh/visualisation/2187019/embed"><script src="https://public.flourish.studio/resources/embed.js"></script></div>
""")
# Out:
# <div class="flourish-embed flourish-bar-chart-race" data-src="visualisation/2187019" data-url="https://flo.uri.sh/visualisation/2187019/embed"><script src="https://public.flourish.studio/resources/embed.js"></script></div>
